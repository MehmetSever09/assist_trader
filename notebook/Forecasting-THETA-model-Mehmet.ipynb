# %% [markdown]
# ## THETA FORECASTING

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import ta

from darts import TimeSeries
from darts.dataprocessing.transformers import Scaler
from darts.models import ExponentialSmoothing, TBATS, AutoARIMA, Theta, RNNModel, NBEATSModel
from darts.metrics import mape, rmse

from darts.models import StatsForecastAutoTheta

# %%
df = pd.read_csv("../raw_data/20230613-130102-daily-processed-data.csv")

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df
# Out:
#                timestamp      open      high       low     close      volume  \
# 0    2019-11-18 03:00:00   8504.13   8504.71   8050.00   8183.26  123477.142
# 1    2019-11-19 03:00:00   8183.30   8212.87   8000.00   8131.70  110854.030
# 2    2019-11-20 03:00:00   8131.12   8230.00   8037.50   8094.05   87352.380
# 3    2019-11-21 03:00:00   8094.57   8131.51   7432.00   7621.90  180289.189
# 4    2019-11-22 03:00:00   7621.89   7765.03   6762.73   7262.72  371213.951
# ...                  ...       ...       ...       ...       ...         ...
# 1289 2023-05-30 03:00:00  27722.10  28038.60  27530.00  27680.10  334379.313
# 1290 2023-05-31 03:00:00  27680.00  27825.00  26826.00  27201.10  471381.890
# 1291 2023-06-01 03:00:00  27201.10  27347.90  26600.00  26805.30  404787.572
# 1292 2023-06-02 03:00:00  26805.30  27290.00  26477.60  27227.80  391110.093
# 1293 2023-06-03 03:00:00  27227.80  27340.20  26900.00  27054.90  182464.100
#
# ...

# %%
freq = '1d'
target_col = 'close'
time_col = 'timestamp'
series = TimeSeries.from_dataframe(df, time_col=time_col, value_cols=[target_col], freq=freq)

# %%
model = StatsForecastAutoTheta()

# %%
train, val = series.split_after(pd.Timestamp('2023-01-01'))

# %%
#model.fit(train)
#forecast = model.predict(1)
#print("model {} obtains MAPE: {:.2f}%".format(model, mape(val[0], forecast)))

# %%
forecast = model.fit(train)

# %%
out = model.predict(1)

# %%
# yr = out.time_index[0].year
# mnth = out.time_index[0].month
# day = out.time_index[0].day
# full = f'{yr}-{mnth}-{day}'

# %%
# full

# %%
#forecast1 = model.predict(5)
#print("Model {} obtains RMSE: {:.2f}".format(model, rmse(val[0], forecast1)))

# %%
# forecasts_list1 = []
# # define a for loop for slicing the train set and make forecasts

# for v in range(len(val)):
#     model= StatsForecastAutoTheta()
    
#     while v>=1 and v<len(val):
#         train =train.append(val[0])
#         val=val[1:]
#         model.fit(train)
#         forecasts_list1.append(model.predict(1).pd_dataframe())
#     print(forecasts_list1)

# %%
forecasts_list = []
# define a for loop for slicing the train set and make forecasts

for v in range(len(val)):
    model= StatsForecastAutoTheta()
    
    while v>=1 and v<len(val):
        train =train.append(val[0])
        val=val[1:]
        model.fit(train)
        pred = model.predict(1)
        yr = pred.time_index[0].year
        mnth = pred.time_index[0].month
        day = pred.time_index[0].day
        full = f'{yr}-{mnth}-{day}'
       
        forecasts_list.append((pred.values()[0][0], full))
print(forecasts_list)
# Out:
# [(16618.8671875, '2023-1-2'), (16674.966796875, '2023-1-3'), (16678.224609375, '2023-1-4'), (16846.48046875, '2023-1-5'), (16835.29296875, '2023-1-6'), (16950.169921875, '2023-1-7'), (16947.537109375, '2023-1-8'), (17128.31640625, '2023-1-9'), (17178.505859375, '2023-1-10'), (17429.494140625, '2023-1-11'), (17926.46875, '2023-1-12'), (18813.466796875, '2023-1-13'), (19892.814453125, '2023-1-14'), (20933.392578125, '2023-1-15'), (20894.7109375, '2023-1-16'), (21187.5234375, '2023-1-17'), (21143.056640625, '2023-1-18'), (20707.203125, '2023-1-19'), (21064.833984375, '2023-1-20'), (22612.705078125, '2023-1-21'), (22785.603515625, '2023-1-22'), (22717.42578125, '2023-1-23'), (22915.71484375, '2023-1-24'), (22647.748046875, '2023-1-25'), (23055.244140625, '2023-1-26'), (23013.5703125, '2023-1-27'), (23075.6875, '2023-1-28'), (23027.75, '2023-1-29'), (23723.82421875, '2023-1-30'), (22862.912109375, '2023-1-31'), (23119.38671875, '2023-2-1'), (23716.904296875, '2023-2-2'), (23510.876953125,
# ...

# %%
values = [x[0] for x in forecasts_list]
dates = [x[1] for x in forecasts_list]
data = pd.DataFrame({'predictions':values, 'timestamp': dates})
data['timestamp'] = pd.to_datetime(data['timestamp'])

# %%
data
# Out:
#       predictions  timestamp
# 0    16618.867188 2023-01-02
# 1    16674.966797 2023-01-03
# 2    16678.224609 2023-01-04
# 3    16846.480469 2023-01-05
# 4    16835.292969 2023-01-06
# ..            ...        ...
# 148  27739.765625 2023-05-30
# 149  27689.128906 2023-05-31
# 150  27225.765625 2023-06-01
# 151  26827.464844 2023-06-02
# 152  27219.839844 2023-06-03
#
# [153 rows x 2 columns]

# %%
columns_to_keep = ['timestamp', 'open', 'high', 'low', 'close', 'volat_ATR']
df_simple = df[columns_to_keep]

# %%
df_simple['timestamp'] = df_simple['timestamp'].dt.date
# Out:
# /tmp/ipykernel_9958/146083921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_simple['timestamp'] = df_simple['timestamp'].dt.date

# %%
df
# Out:
#                timestamp      open      high       low     close      volume  \
# 0    2019-11-18 03:00:00   8504.13   8504.71   8050.00   8183.26  123477.142
# 1    2019-11-19 03:00:00   8183.30   8212.87   8000.00   8131.70  110854.030
# 2    2019-11-20 03:00:00   8131.12   8230.00   8037.50   8094.05   87352.380
# 3    2019-11-21 03:00:00   8094.57   8131.51   7432.00   7621.90  180289.189
# 4    2019-11-22 03:00:00   7621.89   7765.03   6762.73   7262.72  371213.951
# ...                  ...       ...       ...       ...       ...         ...
# 1289 2023-05-30 03:00:00  27722.10  28038.60  27530.00  27680.10  334379.313
# 1290 2023-05-31 03:00:00  27680.00  27825.00  26826.00  27201.10  471381.890
# 1291 2023-06-01 03:00:00  27201.10  27347.90  26600.00  26805.30  404787.572
# 1292 2023-06-02 03:00:00  26805.30  27290.00  26477.60  27227.80  391110.093
# 1293 2023-06-03 03:00:00  27227.80  27340.20  26900.00  27054.90  182464.100
#
# ...

# %%
df_simple['timestamp'] = pd.to_datetime(df_simple['timestamp'])
# Out:
# /tmp/ipykernel_9958/2972366239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_simple['timestamp'] = pd.to_datetime(df_simple['timestamp'])

# %%
merged_df = df_simple.merge(data, on='timestamp')

# %%
merged_df
# Out:
#      timestamp     open     high      low    close   volat_ATR   predictions
# 0   2023-01-02  16610.4  16799.0  16541.2  16666.0  348.494688  16618.867188
# 1   2023-01-03  16665.9  16774.0  16600.3  16667.2  336.009353  16674.966797
# 2   2023-01-04  16667.3  16984.6  16645.7  16842.1  336.215828  16678.224609
# 3   2023-01-05  16842.2  16872.8  16740.4  16823.8  321.657555  16846.480469
# 4   2023-01-06  16823.8  17030.0  16664.8  16943.8  324.767729  16835.292969
# ..         ...      ...      ...      ...      ...         ...           ...
# 148 2023-05-30  27722.1  28038.6  27530.0  27680.1  854.472960  27739.765625
# 149 2023-05-31  27680.0  27825.0  26826.0  27201.1  864.796320  27689.128906
# 150 2023-06-01  27201.1  27347.9  26600.0  26805.3  856.446583  27225.765625
# 151 2023-06-02  26805.3  27290.0  26477.6  27227.8  853.300398  26827.464844
# 152 2023-06-03  27227.8  27340.2  26900.0  27054.9  823.793227  27219.839844
#
# [153 rows x 7 columns]

# %%
merged_df.to_csv('merged_data_THETAModel.csv')

# %%
#df.set_index('timestamp', inplace= True)

# %%
df.plot()
val.plot()
# Out:
# Error in callback <function _draw_all_if_interactive at 0x7fe0d0338dc0> (for post_execute):
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~/.pyenv/versions/assist_trader/lib/python3.10/site-packages/matplotlib/pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File ~/.pyenv/versions/assist_trader/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~/.pyenv/versions/assist_trader/lib/python3.10/site-packages/matplotlib/backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
# ...

# %%
values = [x[0] for x in forecasts_list]

# %%
close1 = 1000
open1 = 950
high1= 1050
low1 = 900
prediction_2 = 910
atr_value= 30

# %%
if close1> prediction_2:
    print("short trade")
    take_profit = (close1-prediction_2)/2
    stop_level = atr_value
for close in
