# %%
import pandas as pd

# %%
import ta

# %%
import matplotlib.pyplot as plt

# %%
data_path = ("../raw_data/BTCUSDT_1h.csv")
data = pd.read_csv(data_path)
data.head()
# Out:
#              timestamp      open      high       low     close   volume
# 0  2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00    0.002
# 1  2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00    0.000
# 2  2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12  471.659
# 3  2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42  583.271
# 4  2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90  689.759

# %%
import yfinance as yf

# %%
# !pwd
# Out:
# /Users/IRIS/code/MehmetSever09/assist_trader/notebook

# %%
df_close = data ['close']

# %%
df_open = data ['open']

# %%
df_high = data['high']

# %%
df_low = data['low']

# %%
data['ATR'] = ta.volatility.AverageTrueRange(df_high,df_low,df_close,window = 14).average_true_range()
data
# Out:
#                  timestamp      open      high       low     close     volume  \
# 0      2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00      0.002
# 1      2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00      0.000
# 2      2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12    471.659
# 3      2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42    583.271
# 4      2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90    689.759
# ...                    ...       ...       ...       ...       ...        ...
# 32751  2023-06-03 20:00:00  27239.40  27246.40  27101.00  27147.60  15130.376
# 32752  2023-06-03 21:00:00  27147.70  27173.70  27113.90  27138.80   6229.878
# 32753  2023-06-03 22:00:00  27138.90  27153.60  27000.00  27084.90  15389.644
# 32754  2023-06-03 23:00:00  27084.90  27119.50  27042.00  27052.70   7760.747
# 32755  2023-06-04 00:00:00  27052.80  27069.30  26900.00  26990.00  18405.196
#
#              ATR
# ...

# %%
bol = ta.volatility.BollingerBands(df_close, window = 14, window_dev=2)

# %%
data['bol_lband'] = bol.bollinger_lband()
data.head(20)
# Out:
#               timestamp      open      high       low     close    volume  \
# 0   2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00     0.002
# 1   2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00     0.000
# 2   2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12   471.659
# 3   2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42   583.271
# 4   2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90   689.759
# 5   2019-09-09 01:00:00  10392.59  10412.65  10375.58  10375.58   675.394
# 6   2019-09-09 02:00:00  10375.58  10392.25  10366.57  10391.63   676.206
# 7   2019-09-09 03:00:00  10391.63  10391.63  10391.63  10391.63     0.000
# 8   2019-09-09 04:00:00  10391.63  10391.63  10391.63  10391.63     0.000
# 9   2019-09-09 05:00:00  10316.62  10316.65  10294.29  10296.04    96.462
# 10  2019-09-09 06:00:00  10295.81  10316.68  10267.37  10297.89   682.987
# 11  2019-09-09 07:00:00  10297.89  10316.33  10251.51  10316.30   680.278
# ...

# %%
data['bol_hband'] = bol.bollinger_hband()

# %%
data['bol_avg'] = bol.bollinger_mavg()

# %%
data
# Out:
#                  timestamp      open      high       low     close     volume  \
# 0      2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00      0.002
# 1      2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00      0.000
# 2      2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12    471.659
# 3      2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42    583.271
# 4      2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90    689.759
# ...                    ...       ...       ...       ...       ...        ...
# 32751  2023-06-03 20:00:00  27239.40  27246.40  27101.00  27147.60  15130.376
# 32752  2023-06-03 21:00:00  27147.70  27173.70  27113.90  27138.80   6229.878
# 32753  2023-06-03 22:00:00  27138.90  27153.60  27000.00  27084.90  15389.644
# 32754  2023-06-03 23:00:00  27084.90  27119.50  27042.00  27052.70   7760.747
# 32755  2023-06-04 00:00:00  27052.80  27069.30  26900.00  26990.00  18405.196
#
# ...

# %%
data['vol_keltner_ch_wb'] = ta.volatility.keltner_channel_wband(df_close,df_high, df_low, window = 20,window_atr = 10,original_version=False)
data
# Out:
#                  timestamp      open      high       low     close     volume  \
# 0      2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00      0.002
# 1      2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00      0.000
# 2      2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12    471.659
# 3      2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42    583.271
# 4      2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90    689.759
# ...                    ...       ...       ...       ...       ...        ...
# 32751  2023-06-03 20:00:00  27239.40  27246.40  27101.00  27147.60  15130.376
# 32752  2023-06-03 21:00:00  27147.70  27173.70  27113.90  27138.80   6229.878
# 32753  2023-06-03 22:00:00  27138.90  27153.60  27000.00  27084.90  15389.644
# 32754  2023-06-03 23:00:00  27084.90  27119.50  27042.00  27052.70   7760.747
# 32755  2023-06-04 00:00:00  27052.80  27069.30  26900.00  26990.00  18405.196
#
# ...

# %%
data['vol_keltner_ch_pb'] = ta.volatility.keltner_channel_pband(df_close,df_high, df_low, window = 20,window_atr = 10,original_version=False)
data
# Out:
#                  timestamp      open      high       low     close     volume  \
# 0      2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00      0.002
# 1      2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00      0.000
# 2      2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12    471.659
# 3      2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42    583.271
# 4      2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90    689.759
# ...                    ...       ...       ...       ...       ...        ...
# 32751  2023-06-03 20:00:00  27239.40  27246.40  27101.00  27147.60  15130.376
# 32752  2023-06-03 21:00:00  27147.70  27173.70  27113.90  27138.80   6229.878
# 32753  2023-06-03 22:00:00  27138.90  27153.60  27000.00  27084.90  15389.644
# 32754  2023-06-03 23:00:00  27084.90  27119.50  27042.00  27052.70   7760.747
# 32755  2023-06-04 00:00:00  27052.80  27069.30  26900.00  26990.00  18405.196
#
# ...

# %%
data['vol_keltner_ch_mb']= ta.volatility.keltner_channel_mband(df_close,df_high, df_low, window = 20,window_atr = 10,original_version=False)
data
# Out:
#                  timestamp      open      high       low     close     volume  \
# 0      2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00      0.002
# 1      2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00      0.000
# 2      2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12    471.659
# 3      2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42    583.271
# 4      2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90    689.759
# ...                    ...       ...       ...       ...       ...        ...
# 32751  2023-06-03 20:00:00  27239.40  27246.40  27101.00  27147.60  15130.376
# 32752  2023-06-03 21:00:00  27147.70  27173.70  27113.90  27138.80   6229.878
# 32753  2023-06-03 22:00:00  27138.90  27153.60  27000.00  27084.90  15389.644
# 32754  2023-06-03 23:00:00  27084.90  27119.50  27042.00  27052.70   7760.747
# 32755  2023-06-04 00:00:00  27052.80  27069.30  26900.00  26990.00  18405.196
#
# ...

# %%
data['don_lband'] = ta.volatility.donchian_channel_lband(df_high, df_low, df_close, window=20)
data.head(20)
# Out:
#               timestamp      open      high       low     close    volume  \
# 0   2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00     0.002
# 1   2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00     0.000
# 2   2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12   471.659
# 3   2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42   583.271
# 4   2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90   689.759
# 5   2019-09-09 01:00:00  10392.59  10412.65  10375.58  10375.58   675.394
# 6   2019-09-09 02:00:00  10375.58  10392.25  10366.57  10391.63   676.206
# 7   2019-09-09 03:00:00  10391.63  10391.63  10391.63  10391.63     0.000
# 8   2019-09-09 04:00:00  10391.63  10391.63  10391.63  10391.63     0.000
# 9   2019-09-09 05:00:00  10316.62  10316.65  10294.29  10296.04    96.462
# 10  2019-09-09 06:00:00  10295.81  10316.68  10267.37  10297.89   682.987
# 11  2019-09-09 07:00:00  10297.89  10316.33  10251.51  10316.30   680.278
# ...

# %%
data['don_hband'] = ta.volatility.donchian_channel_hband(df_high, df_low, df_close, window=20)
data.head(20)
# Out:
#               timestamp      open      high       low     close    volume  \
# 0   2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00     0.002
# 1   2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00     0.000
# 2   2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12   471.659
# 3   2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42   583.271
# 4   2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90   689.759
# 5   2019-09-09 01:00:00  10392.59  10412.65  10375.58  10375.58   675.394
# 6   2019-09-09 02:00:00  10375.58  10392.25  10366.57  10391.63   676.206
# 7   2019-09-09 03:00:00  10391.63  10391.63  10391.63  10391.63     0.000
# 8   2019-09-09 04:00:00  10391.63  10391.63  10391.63  10391.63     0.000
# 9   2019-09-09 05:00:00  10316.62  10316.65  10294.29  10296.04    96.462
# 10  2019-09-09 06:00:00  10295.81  10316.68  10267.37  10297.89   682.987
# 11  2019-09-09 07:00:00  10297.89  10316.33  10251.51  10316.30   680.278
# ...

# %%
data['don_mband'] = ta.volatility.donchian_channel_mband(df_high, df_low, df_close, window=20)
data.head(20)
# Out:
#               timestamp      open      high       low     close    volume  \
# 0   2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00     0.002
# 1   2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00     0.000
# 2   2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12   471.659
# 3   2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42   583.271
# 4   2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90   689.759
# 5   2019-09-09 01:00:00  10392.59  10412.65  10375.58  10375.58   675.394
# 6   2019-09-09 02:00:00  10375.58  10392.25  10366.57  10391.63   676.206
# 7   2019-09-09 03:00:00  10391.63  10391.63  10391.63  10391.63     0.000
# 8   2019-09-09 04:00:00  10391.63  10391.63  10391.63  10391.63     0.000
# 9   2019-09-09 05:00:00  10316.62  10316.65  10294.29  10296.04    96.462
# 10  2019-09-09 06:00:00  10295.81  10316.68  10267.37  10297.89   682.987
# 11  2019-09-09 07:00:00  10297.89  10316.33  10251.51  10316.30   680.278
# ...

# %%
data['ulcer_ind'] = ta.volatility.ulcer_index(df_close,window = 14)
data
# Out:
#                  timestamp      open      high       low     close     volume  \
# 0      2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00      0.002
# 1      2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00      0.000
# 2      2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12    471.659
# 3      2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42    583.271
# 4      2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90    689.759
# ...                    ...       ...       ...       ...       ...        ...
# 32751  2023-06-03 20:00:00  27239.40  27246.40  27101.00  27147.60  15130.376
# 32752  2023-06-03 21:00:00  27147.70  27173.70  27113.90  27138.80   6229.878
# 32753  2023-06-03 22:00:00  27138.90  27153.60  27000.00  27084.90  15389.644
# 32754  2023-06-03 23:00:00  27084.90  27119.50  27042.00  27052.70   7760.747
# 32755  2023-06-04 00:00:00  27052.80  27069.30  26900.00  26990.00  18405.196
#
# ...

# %%
data.to_csv('vol_indicators_df_06_06.csv',index = False)

# %%
# !pwd
# Out:
# /Users/IRIS/code/MehmetSever09/assist_trader/notebook

# %%
pd.read_csv('vol_indicators_df_06_06.csv')
# Out:
#                  timestamp      open      high       low     close     volume  \
# 0      2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00      0.002
# 1      2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00      0.000
# 2      2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12    471.659
# 3      2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42    583.271
# 4      2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90    689.759
# ...                    ...       ...       ...       ...       ...        ...
# 32751  2023-06-03 20:00:00  27239.40  27246.40  27101.00  27147.60  15130.376
# 32752  2023-06-03 21:00:00  27147.70  27173.70  27113.90  27138.80   6229.878
# 32753  2023-06-03 22:00:00  27138.90  27153.60  27000.00  27084.90  15389.644
# 32754  2023-06-03 23:00:00  27084.90  27119.50  27042.00  27052.70   7760.747
# 32755  2023-06-04 00:00:00  27052.80  27069.30  26900.00  26990.00  18405.196
#
# ...

# %%
data_pathh = ("../raw_data/int_rate.csv")
df = pd.read_csv(data_pathh)
df.head()
# Out:
#          Country       Category             DateTime  Value Frequency  \
# 0  United States  Interest Rate  1971-08-04T00:00:00   5.50     Daily
# 1  United States  Interest Rate  1971-08-16T00:00:00   5.75     Daily
# 2  United States  Interest Rate  1971-09-01T00:00:00   5.13     Daily
# 3  United States  Interest Rate  1971-10-01T00:00:00   5.13     Daily
# 4  United States  Interest Rate  1971-11-01T00:00:00   5.13     Daily
#
#   HistoricalDataSymbol           LastUpdate
# 0                 FDTR  2011-06-27T00:00:00
# 1                 FDTR  2011-06-27T00:00:00
# 2                 FDTR  2011-06-27T00:00:00
# 3                 FDTR  2011-06-27T00:00:00
# 4                 FDTR  2011-06-27T00:00:00

# %%
df=df.drop(columns=['Country', 'HistoricalDataSymbol','LastUpdate','Category','Frequency'])

# %%
df
# Out:
#                 DateTime  Value
# 0    1971-08-04T00:00:00   5.50
# 1    1971-08-16T00:00:00   5.75
# 2    1971-09-01T00:00:00   5.13
# 3    1971-10-01T00:00:00   5.13
# 4    1971-11-01T00:00:00   5.13
# ..                   ...    ...
# 826  2023-01-31T00:00:00   4.50
# 827  2023-02-01T00:00:00   4.75
# 828  2023-03-22T00:00:00   5.00
# 829  2023-04-30T00:00:00   5.00
# 830  2023-05-03T00:00:00   5.25
#
# [831 rows x 2 columns]

# %%
df.rename({'DateTime': 'timestamp','Value':'InterestRate'}, axis=1, inplace=True)
df
# Out:
#                timestamp  InterestRate
# 0    1971-08-04T00:00:00          5.50
# 1    1971-08-16T00:00:00          5.75
# 2    1971-09-01T00:00:00          5.13
# 3    1971-10-01T00:00:00          5.13
# 4    1971-11-01T00:00:00          5.13
# ..                   ...           ...
# 826  2023-01-31T00:00:00          4.50
# 827  2023-02-01T00:00:00          4.75
# 828  2023-03-22T00:00:00          5.00
# 829  2023-04-30T00:00:00          5.00
# 830  2023-05-03T00:00:00          5.25
#
# [831 rows x 2 columns]

# %%
df_int = df

# %%
df_int.head()
# Out:
#              timestamp  InterestRate
# 0  1971-08-04T00:00:00          5.50
# 1  1971-08-16T00:00:00          5.75
# 2  1971-09-01T00:00:00          5.13
# 3  1971-10-01T00:00:00          5.13
# 4  1971-11-01T00:00:00          5.13

# %%
df_int['timestamp'] = pd.to_datetime(df_int['timestamp'])
df_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     831 non-null    datetime64[ns]
#  1   InterestRate  831 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 13.1 KB

# %%
data_path = ("../raw_data/BTCUSDT_1h.csv")
df_bit = pd.read_csv(data_path)
df_bit
# Out:
#                  timestamp      open      high       low     close     volume
# 0      2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00      0.002
# 1      2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00      0.000
# 2      2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12    471.659
# 3      2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42    583.271
# 4      2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90    689.759
# ...                    ...       ...       ...       ...       ...        ...
# 32751  2023-06-03 20:00:00  27239.40  27246.40  27101.00  27147.60  15130.376
# 32752  2023-06-03 21:00:00  27147.70  27173.70  27113.90  27138.80   6229.878
# 32753  2023-06-03 22:00:00  27138.90  27153.60  27000.00  27084.90  15389.644
# 32754  2023-06-03 23:00:00  27084.90  27119.50  27042.00  27052.70   7760.747
# 32755  2023-06-04 00:00:00  27052.80  27069.30  26900.00  26990.00  18405.196
#
# [32756 rows x 6 columns]

# %%
df_bit['timestamp'] = pd.to_datetime(df_bit['timestamp'])
df_bit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32756 entries, 0 to 32755
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  32756 non-null  datetime64[ns]
#  1   open       32756 non-null  float64
#  2   high       32756 non-null  float64
#  3   low        32756 non-null  float64
#  4   close      32756 non-null  float64
#  5   volume     32756 non-null  float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 1.5 MB

# %%
df_bit['datetime_M'] = df_bit['timestamp'].dt.to_period('M').dt.strftime('%Y-%m')
df_bit.head()
# Out:
#             timestamp      open      high       low     close   volume  \
# 0 2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00    0.002
# 1 2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00    0.000
# 2 2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12  471.659
# 3 2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42  583.271
# 4 2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90  689.759
#
#   datetime_M
# 0    2019-09
# 1    2019-09
# 2    2019-09
# 3    2019-09
# 4    2019-09

# %%
df_int['datetime_M'] = df_int['timestamp'].dt.to_period('M').dt.strftime('%Y-%m')
df_int.head()
# Out:
#    timestamp  InterestRate datetime_M
# 0 1971-08-04          5.50    1971-08
# 1 1971-08-16          5.75    1971-08
# 2 1971-09-01          5.13    1971-09
# 3 1971-10-01          5.13    1971-10
# 4 1971-11-01          5.13    1971-11

# %%
merged_df = pd.merge(df_bit, df_int, on=['datetime_M', 'datetime_M'], how='inner')
merged_df.head()
# Out:
#           timestamp_x      open      high       low     close   volume  \
# 0 2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00    0.002
# 1 2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00    0.000
# 2 2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12  471.659
# 3 2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42  583.271
# 4 2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90  689.759
#
#   datetime_M timestamp_y  InterestRate
# 0    2019-09  2019-09-18           2.0
# 1    2019-09  2019-09-18           2.0
# 2    2019-09  2019-09-18           2.0
# 3    2019-09  2019-09-18           2.0
# 4    2019-09  2019-09-18           2.0

# %%
bitinr = merged_df.drop(['datetime_M','timestamp_y'],axis = 1)
bitinr
# Out:
#               timestamp_x      open      high       low     close     volume  \
# 0     2019-09-08 20:00:00  10000.00  10000.00  10000.00  10000.00      0.002
# 1     2019-09-08 21:00:00  10000.00  10000.00  10000.00  10000.00      0.000
# 2     2019-09-08 22:00:00  10344.77  10357.53  10337.43  10340.12    471.659
# 3     2019-09-08 23:00:00  10340.12  10368.64  10334.54  10351.42    583.271
# 4     2019-09-09 00:00:00  10351.42  10391.90  10324.77  10391.90    689.759
# ...                   ...       ...       ...       ...       ...        ...
# 33423 2023-05-31 19:00:00  26900.00  26972.90  26826.00  26928.70  18949.974
# 33424 2023-05-31 20:00:00  26928.70  27077.00  26902.50  27044.30  17181.927
# 33425 2023-05-31 21:00:00  27044.40  27086.70  27006.10  27027.70  10554.941
# 33426 2023-05-31 22:00:00  27027.80  27121.10  26981.50  26999.50  12017.111
# 33427 2023-05-31 23:00:00  26999.50  27106.20  26992.00  27096.90   8568.793
#
#        InterestRate
# 0              2.00
# ...
